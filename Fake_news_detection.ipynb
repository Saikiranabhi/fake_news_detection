# %%
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re
import joblib
import string

# %%
fake = pd.read_csv('Fake.csv')
true = pd.read_csv('True.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['class'] = 0
true['class'] = 1

# %%
data = pd.concat([fake,true],axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 13288  WATCH: REMEMBER WHEN HILLARY SAID She Wasn’t D...
# 12268  FOX HOST KENNEDY Gives Jill Stein An Earful: ‘...
# 10610  Clinton sets sights on Trump, general election...
# 18264  Nerve agent VX found on shirts of women accuse...
# 8842   IMF's Lagarde warns against Trump-style protec...
# 17971  Fox News Cuts Off Terror Expert Before He Coul...
# 13364  BREAKING: HERE’S WHY HILLARY’S “Khan Man” Just...
# 835     WATCH: Mitch McConnell Gets His A** Handed To...
# 19839  LIBERAL HACK ALEC BALDWIN Performed Rank Trump...
# 19402  Russia says will target U.S.-backed fighters i...
#
#                                                     text       subject  \
# 13288  That Hillary, she sure is a forked-tongued sil...      politics
# 12268                                                         politics
# 10610  COLUMBIA, S.C. (Reuters) - Riding high after a...  politicsNews
# ...

# %%
data = data.drop(['title','subject','date'],axis=1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis=1,inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 16538  What in the world is it with Obama and crimina...      0
# 38745  MARIB, Yemen (Reuters) - At a hospital in the ...      1
# 26005  WASHINGTON (Reuters) - U.S. Energy Secretary R...      1
# 43632  TUNIS (Reuters) - Tunisia s parliament on Wedn...      1
# 17979  Kid Rock hasn t officially announced his run f...      0

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]',"",text)
    text = re.sub(r"\w*\d\w*","",text)
    text = re.sub(r"https?:://\S+|www\.\S+","",text)
    text = re.sub("<.*?>+","",text)
    text = re.sub("[%s]"%re.escape(string.punctuation),"",text)
    text = re.sub("\n","",text)
    text = re.sub(r"\w*\d\w*","",text)
    return text

# %%
data["text"] = data["text"].apply(clean_text)

# %%
x = data["text"]
y = data["class"]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
#print("NaN in x_train:", pd.Series(x_train).isna().sum())
#print("Empty strings in x_train:", (pd.Series(x_train).str.strip() == '').sum())

# %%
'''
x_train = pd.Series(x_train)
x_test = pd.Series(x_test)
# Remove NaN and empty strings
x_train = x_train.dropna()
x_train = x_train[x_train.str.strip() != '']

# Do the same for test data if needed
x_test = x_test.dropna()
x_test = x_test[x_test.str.strip() != '']
'''
# Out:
# "\nx_train = pd.Series(x_train)\nx_test = pd.Series(x_test)\n# Remove NaN and empty strings\nx_train = x_train.dropna()\nx_train = x_train[x_train.str.strip() != '']\n\n# Do the same for test data if needed\nx_test = x_test.dropna()\nx_test = x_test[x_test.str.strip() != '']\n"

# %%
'''
print("NaN in x_train:", pd.Series(x_train).isna().sum())
print("Empty strings in x_train:", (pd.Series(x_train).str.strip() == '').sum())
'''
# Out:
# '\nprint("NaN in x_train:", pd.Series(x_train).isna().sum())\nprint("Empty strings in x_train:", (pd.Series(x_train).str.strip() == \'\').sum())\n'

# %%
vectorizer = TfidfVectorizer()
xv_train = vectorizer.fit_transform(x_train)
xv_test = vectorizer.transform(x_test)

# %%
lr = LogisticRegression()
lr.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
prediction = lr.predict(xv_test)
lr.score(xv_test,y_test)
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5895
#            1       0.98      0.99      0.98      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']
